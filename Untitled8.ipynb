# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivamfrontterrain-cmd/waifu/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/waifu
# !pip install -r requirements.txt
# !python scraper.py
# Out:
# /content/waifu
# ...
# 02:34:52 [INFO] Connecting to Telegram client...
# 02:34:54 [INFO] Successfully logged in as: Zoro (@RoronoaZoroTG) [ID: 7997611673]
# 02:34:54 [INFO] Parallel download workers: 12 active streams
# 02:34:54 [INFO] Looking for chat folder: 'databases'...
# 02:34:54 [INFO] Found folder 'databases'! Extracting channels...
# 02:35:02 [INFO] Discovered 37 channels/chats inside folder 'databases'.
# 02:35:02 [INFO]   1. GALAXY ART DATABASE (ID: 4474823590)
# 02:35:02 [INFO]   2. Gases's bot update (ID: 4455299574)
# 02:35:02 [INFO]   3. 𝗔𝗻𝗶𝗺𝗲 𝗖𝗵𝗮𝗿𝗮𝗰𝘁𝗲𝗿 𝗕𝗼𝘁 Database 𝗖𝗵𝗮𝗻𝗻𝗲𝗹 (ID: 4397263975)
# 02:35:02 [INFO]   4. Capture Fantasy Database (ID: 4369202061)
# 02:35:02 [INFO]   5. HoshiVerse Database (ID: 4246786379)
# 02:35:02 [INFO]   6. 𝑪𝒉𝒂𝒓𝒂𝒄𝒕𝒆𝒓 𝑪𝒐𝒍𝒍𝒆𝒄𝒕𝒆𝒓𝒔 𝑶𝒇𝒇𝒊𝒄𝒊𝒂𝒍-𝑪𝒉𝒂𝒏𝒏𝒆𝒍 (ID: 3997871300)
# 02:35:02 [INFO]   7. Bika Waifu Database (ID: 3923540741)
# 02:35:02 [INFO]   8. GALAXY DATABASE (ID: 3902279711)
# 02:35:02 [INFO]   9. 𝑻𝒂𝒌𝒆𝒓𝒔 𝑫𝒂𝒕𝒂𝒃𝒂𝒔𝒆 (ID: 3899587473)
# ...

# %%
# %%writefile /content/waifu/.env
# TG_API_ID=37839156
# TG_API_HASH=5d13fd9f323e42a304bb229f36eefa8d
# TG_PHONE=+919365018715
# FOLDER_NAME=databases
# DOWNLOAD_IMAGES=true
# CONCURRENT_DOWNLOADS=12
# IMAGE_DIR=downloads/images
# DATABASE_DIR=database
# DB_FILE=database/waifus.db
# EXPORT_JSON=database/waifus.json
# EXPORT_CSV=database/waifus.csv
# SESSION_NAME=waifu_session
# Out:
# Writing /content/waifu/.env
